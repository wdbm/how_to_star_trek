# %%
import pandas
# import productivity from COVID19_lockdown

# %%
df = pandas.read_csv('TNG.csv')
df.head()
# Out:
#    number_overall  number_in_season  season                           title  \
# 0               1                 1       1   Encounter at Farpoint, Part I
# 1               2                 2       1  Encounter at Farpoint, Part II
# 2               3                 3       1                   The Naked Now
# 3               4                 4       1                   Code of Honor
# 4               5                 5       1                The Last Outpost
#
#   essential_watching quality_wbm favourite_wbm  \
# 0                yes         meh           NaN
# 1                yes         meh           NaN
# 2              maybe         meh           NaN
# 3              maybe         bad           NaN
# 4              maybe          ok           NaN
#
#                                         comments_wbm broadcast_date  stardate  \
# 0                                                NaN     1987-09-28   41153.7
# ...

# %%
df.query('essential_watching in ["yes", "maybe"]').head()
# Out:
#    number_overall  number_in_season  season                           title  \
# 0               1                 1       1   Encounter at Farpoint, Part I
# 1               2                 2       1  Encounter at Farpoint, Part II
# 2               3                 3       1                   The Naked Now
# 3               4                 4       1                   Code of Honor
# 4               5                 5       1                The Last Outpost
#
#   essential_watching quality_wbm favourite_wbm  \
# 0                yes         meh           NaN
# 1                yes         meh           NaN
# 2              maybe         meh           NaN
# 3              maybe         bad           NaN
# 4              maybe          ok           NaN
#
#                                         comments_wbm broadcast_date  stardate  \
# 0                                                NaN     1987-09-28   41153.7
# ...
